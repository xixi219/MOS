# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_clean = pd.read_csv('/home/alexis/_momo/df_test_clean.csv')
df_snr25 = pd.read_csv('/home/alexis/_momo/df_test_snr25.csv')
df_snr20 = pd.read_csv('/home/alexis/_momo/df_test_snr20.csv')
df_snr15 = pd.read_csv('/home/alexis/_momo/df_test_snr15.csv')
df_train_clean = pd.read_csv('/home/alexis/_momo/df_train_clean.csv')

# the 20 MOSes
targets = ['OVRL_raw', 'SIG_raw', 'BAK_raw', 'OVRL', 'SIG', 'BAK', 'P808_MOS', 
           'mos_pred', 'noi_pred', 'dis_pred', 'col_pred', 'loud_pred', 'MOS_SSL', 
           'MOS_COL', 'MOS_DISC', 'MOS_LOUD', 'MOS_NOISE', 'MOS_REVERB', 'MOS_SIG', 'MOS_OVRL']

# %%
num_rows = 5
num_cols = 4
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
fig.suptitle('Distribution of the MOSes in [clean, snr25, snr20, snr15]', y=1.02)

for i, target in enumerate(targets):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]
    
    ## histplot displays the distribution of data using a histogram
    ## showing the "frequency" of observations in predefined bins
    sns.histplot(df_clean[target], kde=True, label='df_clean', bins=50, ax=ax)
    sns.histplot(df_snr25[target], kde=True, label='df_snr25', bins=50, ax=ax)
    sns.histplot(df_snr20[target], kde=True, label='df_snr20', bins=50, ax=ax)
    sns.histplot(df_snr15[target], kde=True, label='df_snr15', bins=50, ax=ax)
    # sns.histplot(df_train_clean[target], kde=True, label='df_train_clean', bins=50, ax=ax)
    ax.set_title(target)
    ax.set_xlabel('mos')
    ax.set_ylabel('frequency')
    ax.legend()
    
plt.tight_layout(rect=[0, 0, 1, 1])
plt.show()

# %%
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
fig.suptitle('Kernel Density Estimation of the MOSes in [clean, snr25, snr20, snr15]', y=1.02)

for i, target in enumerate(targets):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]
    
    ## kdeplot provides a smooth estimate of the "probability density" function using a kernel density estimation
    ## offering a continuous, smoothed representation of the data distribution.
    sns.kdeplot(df_clean[target], label='df_clean', fill=True, ax=ax)
    sns.kdeplot(df_snr25[target], label='df_snr25', fill=True, ax=ax)
    sns.kdeplot(df_snr20[target], label='df_snr20', fill=True, ax=ax)
    sns.kdeplot(df_snr15[target], label='df_snr15', fill=True, ax=ax)
    sns.kdeplot(df_train_clean[target], label='df_train_clean', fill=True, ax=ax)
    ax.set_title(target)
    ax.set_xlabel('mos')
    ax.set_ylabel('density')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 1])
plt.show()
